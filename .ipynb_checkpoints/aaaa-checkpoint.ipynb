# %%
#导入需要的库
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = None #显示完整打印数据
pd.options.display.max_rows = None
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei'] # 用来正常显示中文
plt.rcParams['axes.unicode_minus']=False    # 用来正常显示负号
plt.rcParams['figure.dpi'] = 150 # 修改图片分辨率
plt.rcParams.update({'font.size': 16}) # 修改图片整体字体大小
import numpy as np
import warnings
warnings.filterwarnings("ignore") # 忽略警告
# 读取数据集
data = pd.read_excel('肠癌18月无进展分类（终版）.xlsx')
# 删除无关建模列
data = data.drop(['医院住院序号','医院病人编号'],axis=1)
# 查看数据类型分布，发现存在需要编码的数据
data.dtypes
# Out:
# 年龄                     int64
# 性别                     int64
# 民族                     int64
# 身高                   float64
# 体重                   float64
# BMI                  float64
# 既往化疗周期数                int64
# 肠癌手术史                  int64
# 原发肿瘤部位                 int64
# 原发肿瘤位置                 int64
# 组织学分级                float64
# 进展期表现                  int64
# 组织学分型                  int64
# 肿瘤最大直径               float64
# 淋巴结转移                  int64
# T                    float64
# N                      int64
# M                      int64
# 肿瘤分期                   int64
# VEGF                 float64
# MSIH                 float64
# KRAS                 float64
# NRAS                 float64
# BRAF                 float64
# 联合靶向药物                 int64
# 周期数                    int64
# 完成推荐化疗周期               int64
# 放疗                     int64
# 消化道癌家族史                int64
# 高血压                    int64
# 糖尿病                    int64
# 冠心病                    int64
# 前列腺增生                  int64
# 肾结石                    int64
# 胆结石                    int64
# 慢性胃炎                   int64
# 十二指肠溃疡                 int64
# 胆囊炎                    int64
# 脂肪肝                    int64
# 肝硬化                    int64
# 肝囊肿                    int64
# 肾囊肿                    int64
# 高脂血症                   int64
# 痛风                     int64
# 脑梗                     int64
# 化后恶心呕吐                 int64
# 化后吞咽困难                 int64
# 化后骨髓抑制                 int64
# 化后肝功能异常                int64
# NRS评分                  int64
# ECOG评分                 int64
# 癌胚抗原(CEA)            float64
# 甲胎蛋白(AFP)            float64
# 糖类抗原125(CA125)       float64
# 糖类抗原153(CA153)       float64
# 糖类抗原199(CA199)       float64
# 糖类抗原242(CA242)       float64
# 糖类抗原50(CA50)         float64
# 糖类抗原724(CA724)       float64
# 铁蛋白(FER)             float64
# 胸苷激酶1(TK1)           float64
# 热休克蛋白90α(Hsp90a)     float64
# 单克隆抗体隐血检测(OB(Hb))    float64
# 白细胞计数(WBC)           float64
# 超敏C反应蛋白(hsCRP)       float64
# 单核细胞率(MONO%)         float64
# 单核细胞数(MONO)          float64
# 红细胞分布宽度(RDWSD)       float64
# 红细胞平均体积(MCV)         float64
# 红细胞平均血红蛋白含量(MCH)     float64
# 红细胞平均血红蛋白浓度(MCHC)    float64
# 红细胞数(RBC)            float64
# 红细胞压积(HCT)           float64
# 淋巴细胞率(LYMPH%)        float64
# 淋巴细胞数(LYMPH)         float64
# 嗜碱性粒细胞率(BASO%)       float64
# 嗜碱性粒细胞数(SJXLXB)      float64
# 嗜酸性粒细胞率(EOS%)        float64
# 嗜酸性粒细胞数(SSXLXB)      float64
# 血红蛋白(HGB)            float64
# 血小板计数(PLT)           float64
# 中性粒细胞率(NEUT%)        float64
# 中性粒细胞数(NEUT)         float64
# 5核苷酸酶(5NT)           float64
# αL岩藻糖苷酶(AFU)         float64
# α羟丁酸脱氢酶(αHBDH)       float64
# γ谷氨酰转肽酶(GGT)         float64
# 白蛋白(ALB)             float64
# 白球比(A/G)             float64
# 丙氨酸氨基转移酶(ALT)        float64
# 胆碱脂酶(CHE)            float64
# 低密度脂蛋白胆固醇(DMDZDB)    float64
# 二氧化碳(CO2)            float64
# 钙(Ca)                float64
# 甘油三酯(TG)             float64
# 高密度脂蛋白胆固醇(GMDZDB)    float64
# 估算肾小球滤过率(eGFR)       float64
# 谷草/谷丙(AST/ALT)       float64
# 胱抑素C(Cys_C)          float64
# 肌酐(Cr)               float64
# 肌酸激酶(CK)             float64
# 钾(K)                 float64
# 间接胆红素(IBIL)          float64
# 碱性磷酸酶(ALP)           float64
# 磷(P)                 float64
# 氯(Cl)                float64
# 镁(Mg)                float64
# 钠(Na)                float64
# 尿素(Urea)             float64
# 尿素/肌酐(U/C)           float64
# 尿酸(UA)               float64
# 葡萄糖(GLU)             float64
# 前白蛋白(PA)             float64
# 球蛋白(GLB)             float64
# 乳酸脱氢酶(LDH)           float64
# 渗透压(OSM)             float64
# 天冬氨酸氨基转移酶(AST)       float64
# 同型半胱氨酸(HCY)          float64
# 腺苷脱氨酶(ADA)           float64
# 阴离子间隙(AG)            float64
# 载脂蛋白A1(ApoA)         float64
# 载脂蛋白B(ApoB)          float64
# 脂蛋白(a)(LPa)          float64
# 直接胆红素(DBIL)          float64
# 总胆固醇(CHOL)           float64
# 总胆红素(TBIL)           float64
# 总胆汁酸(TBA)            float64
# 总蛋白(TP)              float64
# 18个月肿瘤进展情况             int64
# dtype: object

# %%
# 检查每列缺失值个数，存在缺失值
data.isnull().sum()
# Out:
# 年龄                     0
# 性别                     0
# 民族                     0
# 身高                    25
# 体重                     1
# BMI                   25
# 既往化疗周期数                0
# 肠癌手术史                  0
# 原发肿瘤部位                 0
# 原发肿瘤位置                 0
# 组织学分级                 88
# 进展期表现                  0
# 组织学分型                  0
# 肿瘤最大直径               101
# 淋巴结转移                  0
# T                     35
# N                      0
# M                      0
# 肿瘤分期                   0
# VEGF                 183
# MSIH                 184
# KRAS                 371
# NRAS                 387
# BRAF                 375
# 联合靶向药物                 0
# 周期数                    0
# 完成推荐化疗周期               0
# 放疗                     0
# 消化道癌家族史                0
# 高血压                    0
# 糖尿病                    0
# 冠心病                    0
# 前列腺增生                  0
# 肾结石                    0
# 胆结石                    0
# 慢性胃炎                   0
# 十二指肠溃疡                 0
# 胆囊炎                    0
# 脂肪肝                    0
# 肝硬化                    0
# 肝囊肿                    0
# 肾囊肿                    0
# 高脂血症                   0
# 痛风                     0
# 脑梗                     0
# 化后恶心呕吐                 0
# 化后吞咽困难                 0
# 化后骨髓抑制                 0
# 化后肝功能异常                0
# NRS评分                  0
# ECOG评分                 0
# 癌胚抗原(CEA)             15
# 甲胎蛋白(AFP)            134
# 糖类抗原125(CA125)        66
# 糖类抗原153(CA153)       182
# 糖类抗原199(CA199)        16
# 糖类抗原242(CA242)       305
# 糖类抗原50(CA50)         269
# 糖类抗原724(CA724)       175
# 铁蛋白(FER)             367
# 胸苷激酶1(TK1)           257
# 热休克蛋白90α(Hsp90a)     162
# 单克隆抗体隐血检测(OB(Hb))    342
# 白细胞计数(WBC)            86
# 超敏C反应蛋白(hsCRP)       207
# 单核细胞率(MONO%)           2
# 单核细胞数(MONO)            1
# 红细胞分布宽度(RDWSD)        59
# 红细胞平均体积(MCV)           1
# 红细胞平均血红蛋白含量(MCH)       1
# 红细胞平均血红蛋白浓度(MCHC)      1
# 红细胞数(RBC)              1
# 红细胞压积(HCT)             1
# 淋巴细胞率(LYMPH%)          1
# 淋巴细胞数(LYMPH)           1
# 嗜碱性粒细胞率(BASO%)        67
# 嗜碱性粒细胞数(SJXLXB)       31
# 嗜酸性粒细胞率(EOS%)         68
# 嗜酸性粒细胞数(SSXLXB)       17
# 血红蛋白(HGB)              1
# 血小板计数(PLT)             1
# 中性粒细胞率(NEUT%)          1
# 中性粒细胞数(NEUT)           1
# 5核苷酸酶(5NT)            74
# αL岩藻糖苷酶(AFU)          43
# α羟丁酸脱氢酶(αHBDH)       316
# γ谷氨酰转肽酶(GGT)           2
# 白蛋白(ALB)               2
# 白球比(A/G)               2
# 丙氨酸氨基转移酶(ALT)          2
# 胆碱脂酶(CHE)              2
# 低密度脂蛋白胆固醇(DMDZDB)    293
# 二氧化碳(CO2)              3
# 钙(Ca)                  2
# 甘油三酯(TG)             247
# 高密度脂蛋白胆固醇(GMDZDB)    247
# 估算肾小球滤过率(eGFR)         3
# 谷草/谷丙(AST/ALT)         2
# 胱抑素C(Cys_C)           38
# 肌酐(Cr)                 2
# 肌酸激酶(CK)             227
# 钾(K)                   4
# 间接胆红素(IBIL)            2
# 碱性磷酸酶(ALP)             2
# 磷(P)                   5
# 氯(Cl)                  3
# 镁(Mg)                  5
# 钠(Na)                  3
# 尿素(Urea)               2
# 尿素/肌酐(U/C)             2
# 尿酸(UA)                 2
# 葡萄糖(GLU)               2
# 前白蛋白(PA)              43
# 球蛋白(GLB)               2
# 乳酸脱氢酶(LDH)             2
# 渗透压(OSM)               3
# 天冬氨酸氨基转移酶(AST)         2
# 同型半胱氨酸(HCY)          249
# 腺苷脱氨酶(ADA)            45
# 阴离子间隙(AG)              4
# 载脂蛋白A1(ApoA)         247
# 载脂蛋白B(ApoB)          247
# 脂蛋白(a)(LPa)          247
# 直接胆红素(DBIL)            2
# 总胆固醇(CHOL)           247
# 总胆红素(TBIL)             2
# 总胆汁酸(TBA)             39
# 总蛋白(TP)                2
# 18个月肿瘤进展情况             0
# dtype: int64
